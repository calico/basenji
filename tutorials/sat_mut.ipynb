# %% [markdown]
# Saturation mutagenesis is a powerful tool both for dissecting a specific sequence of interest and understanding what the model learned. [basenji_sat.py](https://github.com/calico/basenji/blob/master/bin/basenji_sat.py) enables this analysis from a test set of data. [basenji_sat_vcf.py](https://github.com/calico/basenji/blob/master/bin/basenji_sat_vcf.py) lets you provide a VCF file for variant-centered mutagenesis.
#
# To do this, you'll need
#  * Trained model
#  * Input file (FASTA or HDF5 with test_in/test_out)

# %% [markdown]
# First, you can either train your own model in the [Train/test tutorial](https://github.com/calico/basenji/blob/master/tutorials/train_test.ipynb) or download one that I pre-trained.

# %%
import os, subprocess

if not os.path.isfile('models/gm12878.tf.meta'):
    subprocess.call('curl -o models/gm12878.tf.index https://storage.googleapis.com/basenji_tutorial_data/model_gm12878.tf.index', shell=True)
    subprocess.call('curl -o models/gm12878.tf.meta https://storage.googleapis.com/basenji_tutorial_data/model_gm12878.tf.meta', shell=True)
    subprocess.call('curl -o models/gm12878.tf.data-00000-of-00001 https://storage.googleapis.com/basenji_tutorial_data/model_gm12878.tf.data-00000-of-00001', shell=True)

# %% [markdown]
# We'll bash the PIM1 promoter to see what motifs drive its expression. I placed a 262 kb FASTA file surrounding the PIM1 TSS in data/pim1.fa, so we'll use [basenji_sat.py](https://github.com/calico/basenji/blob/master/bin/basenji_sat.py).
#
# The most relevant options are:
#
# | Option/Argument | Value | Note |
# |:---|:---|:---|
# | -g | data/human.hg19.genome | Genome assembly chromosome length to bound gene sequences. |
# | -f | 20 | Figure width, that I usually scale to 10x the saturation mutageneis region |
# | -l | 200 | Saturation mutagenesis region in the center of the given sequence(s) |
# | -o | pim1_sat | Outplot plot directory. |
# | -t | 0,38 | Target indexes. 0 is a DNase and 38 is CAGE, as you can see in data/gm12878_wigs.txt. |
# | params_file | models/params_small_sat.txt | Table of parameters to setup the model architecture and optimization parameters. |
# | model_file | models/gm12878.tf | Trained saved model prefix. |
# | input_file | data/pim1.fa | Either FASTA or HDF5 with test_in/test_out keys. |

# %%
! basenji_sat.py -f 20 -l 200 -o pim1_sat -t 0,38 models/params_small_sat.txt models/gm12878.tf data/pim1.fa
# Out:
# {'target_pool': 128, 'num_targets': 39, 'cnn_filters': [128, 128, 160, 200, 250, 256], 'dense': 1, 'learning_rate': 0.002, 'loss': 'poisson', 'dcnn_filter_sizes': [3, 3, 3, 3, 3, 3], 'full_dropout': 0.05, 'link': 'softplus', 'adam_beta2': 0.98, 'cnn_filter_sizes': [22, 1, 6, 6, 6, 3], 'cnn_dropout': 0.05, 'dcnn_dropout': 0.1, 'batch_renorm': 1, 'adam_beta1': 0.97, 'full_units': 384, 'batch_buffer': 16384, 'dcnn_filters': [32, 32, 32, 32, 32, 32], 'batch_size': 1, 'cnn_pool': [1, 2, 4, 4, 4, 1]}
# Targets pooled by 128 to length 2048
# Convolution w/ 128 4x22 filters strided by 1
# Batch normalization
# ReLU
# Dropout w/ probability 0.050
# Convolution w/ 128 128x1 filters strided by 1
# Batch normalization
# ReLU
# Max pool 2
# Dropout w/ probability 0.050
# Convolution w/ 160 128x6 filters strided by 1
# Batch normalization
# ReLU
# Max pool 4
# Dropout w/ probability 0.050
# Convolution w/ 200 160x6 filters strided by 1
# Batch normalization
# ReLU
# Max pool 4
# Dropout w/ probability 0.050
# Convolution w/ 250 200x6 filters strided by 1
# Batch normalization
# ReLU
# Max pool 4
# Dropout w/ probability 0.050
# Convolution w/ 256 250x3 filters strided by 1
# Batch normalization
# ReLU
# Dropout w/ probability 0.050
# Dilated convolution w/ 32 256x3 rate 2 filters
# Batch normalization
# ReLU
# Dropout w/ probability 0.100
# Dilated convolution w/ 32 288x3 rate 4 filters
# Batch normalization
# ReLU
# Dropout w/ probability 0.100
# Dilated convolution w/ 32 320x3 rate 8 filters
# Batch normalization
# ReLU
# Dropout w/ probability 0.100
# Dilated convolution w/ 32 352x3 rate 16 filters
# Batch normalization
# ReLU
# Dropout w/ probability 0.100
# Dilated convolution w/ 32 384x3 rate 32 filters
# Batch normalization
# ReLU
# Dropout w/ probability 0.100
# Dilated convolution w/ 32 416x3 rate 64 filters
# Batch normalization
# ReLU
# Dropout w/ probability 0.100
# Linear transformation 448x384
# Batch normalization
# ReLU
# Dropout w/ probability 0.050
# Linear transform 384x39x1
# Model building time 8.525379
# 2017-09-10 08:39:50.762828: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use SSE4.2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-10 08:39:50.762862: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-10 08:39:50.762867: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use AVX2 instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-10 08:39:50.762871: W tensorflow/core/platform/cpu_feature_guard.cc:45] The TensorFlow library wasn't compiled to use FMA instructions, but these are available on your machine and could speed up CPU computations.
# 2017-09-10 08:39:54.494688: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.495315: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.495894: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.496514: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.497125: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.497739: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.499473: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.499857: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.500248: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.500320: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.500732: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.500776: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.501234: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.501589: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.502047: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.502090: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.502132: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.502912: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.503119: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.503190: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.503365: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.503894: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.504044: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.504143: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.504216: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.504332: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.504754: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.504939: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.505139: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.505289: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.505310: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.505974: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.506187: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.506212: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.506327: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.506598: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.506690: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.507256: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.507455: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.507710: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.507765: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.507807: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.508014: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.508617: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.508972: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.509085: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.509099: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.509114: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.509142: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.509613: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.510068: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.510689: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.510718: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.510773: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.510802: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.510820: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.511036: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.511771: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.512076: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.512346: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.512390: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.512395: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.512420: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.512989: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.513252: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.513683: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.513840: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.513970: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.514281: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.514394: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.514524: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.515234: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.515534: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.515777: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.515911: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.516072: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.516810: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.516853: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.517031: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.517107: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.517143: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.517534: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.518211: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.518314: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.518387: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.518767: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.518836: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.519308: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.519311: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.520071: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.520122: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.520127: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.520205: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.520532: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.520611: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.520626: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.521211: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.521774: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.521875: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.521890: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.521952: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.521997: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.522076: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.522635: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.523174: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.523237: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.523423: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.523462: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.523742: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.523820: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.523879: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.524526: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.524754: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.524803: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.524971: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.525106: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.525500: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.525967: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.526014: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.526135: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.526191: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.526203: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.526755: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.527229: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.527235: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.527338: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.527352: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.527464: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.527881: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.528100: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.528683: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.528788: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.528908: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.528952: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.528960: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.529348: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.529949: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.530023: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.530091: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.530274: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.530465: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.530616: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.531187: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.531550: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.531562: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.531609: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.531737: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.531766: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.532362: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.532835: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.533014: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.533101: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.533159: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.533196: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.533406: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.533836: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.534561: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.534724: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.534784: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.534785: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.534795: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.534840: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.535103: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.535716: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.536009: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.536183: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.536650: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.536875: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.536966: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.537085: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.537200: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.537810: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.537882: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.538032: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.538062: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.538354: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.538485: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.539116: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.539143: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.539196: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.539313: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.539581: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.539708: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.540361: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.540430: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.540502: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.540700: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.540848: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.541153: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.541499: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.541821: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.542020: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.542149: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.542159: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.542275: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.542300: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.542967: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.543400: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.543825: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.543933: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.543972: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.543990: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.544043: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.544182: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.544265: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.544574: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# 2017-09-10 08:39:54.544629: W tensorflow/core/framework/op_kernel.cc:1158] Data loss: not an sstable (bad magic number)
# Traceback (most recent call last):
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py", line 1139, in _do_call
#     return fn(*args)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py", line 1121, in _run_fn
#     status, run_metadata)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/contextlib.py", line 66, in __exit__
#     next(self.gen)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/errors_impl.py", line 466, in raise_exception_on_not_ok_status
#     pywrap_tensorflow.TF_GetCode(status))
# tensorflow.python.framework.errors_impl.DataLossError: not an sstable (bad magic number)
# 	 [[Node: save/RestoreV2_206 = RestoreV2[dtypes=[DT_INT64], _device="/job:localhost/replica:0/task:0/cpu:0"](_arg_save/Const_0_0, save/RestoreV2_206/tensor_names, save/RestoreV2_206/shape_and_slices)]]
#
# During handling of the above exception, another exception occurred:
#
# Traceback (most recent call last):
#   File "/Users/davidkelley/code/Basenji/bin/basenji_sat.py", line 575, in <module>
#     main()
#   File "/Users/davidkelley/code/Basenji/bin/basenji_sat.py", line 124, in main
#     saver.restore(sess, model_file)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1548, in restore
#     {self.saver_def.filename_tensor_name: save_path})
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py", line 789, in run
#     run_metadata_ptr)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py", line 997, in _run
#     feed_dict_string, options, run_metadata)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py", line 1132, in _do_run
#     target_list, options, run_metadata)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/client/session.py", line 1152, in _do_call
#     raise type(e)(node_def, op, message)
# tensorflow.python.framework.errors_impl.DataLossError: not an sstable (bad magic number)
# 	 [[Node: save/RestoreV2_206 = RestoreV2[dtypes=[DT_INT64], _device="/job:localhost/replica:0/task:0/cpu:0"](_arg_save/Const_0_0, save/RestoreV2_206/tensor_names, save/RestoreV2_206/shape_and_slices)]]
#
# Caused by op 'save/RestoreV2_206', defined at:
#   File "/Users/davidkelley/code/Basenji/bin/basenji_sat.py", line 575, in <module>
#     main()
#   File "/Users/davidkelley/code/Basenji/bin/basenji_sat.py", line 120, in main
#     saver = tf.train.Saver()
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1139, in __init__
#     self.build()
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 1170, in build
#     restore_sequentially=self._restore_sequentially)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 691, in build
#     restore_sequentially, reshape)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 407, in _AddRestoreOps
#     tensors = self.restore_op(filename_tensor, saveable, preferred_shard)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/training/saver.py", line 247, in restore_op
#     [spec.tensor.dtype])[0])
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/ops/gen_io_ops.py", line 640, in restore_v2
#     dtypes=dtypes, name=name)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/op_def_library.py", line 767, in apply_op
#     op_def=op_def)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 2506, in create_op
#     original_op=self._default_original_op, op_def=op_def)
#   File "/Users/davidkelley/anaconda3/lib/python3.5/site-packages/tensorflow/python/framework/ops.py", line 1269, in __init__
#     self._traceback = _extract_stack()
#
# DataLossError (see above for traceback): not an sstable (bad magic number)
# 	 [[Node: save/RestoreV2_206 = RestoreV2[dtypes=[DT_INT64], _device="/job:localhost/replica:0/task:0/cpu:0"](_arg_save/Const_0_0, save/RestoreV2_206/tensor_names, save/RestoreV2_206/shape_and_slices)]]

# %% [markdown]
# The saturated mutagenesis heatmaps go into pim1_sat

# %%
from IPython.display import IFrame
IFrame('pim1_sat/seq0_t0.pdf', width=1200, height=400)
# Out:
#         <iframe
#             width="1200"
#             height="400"
#             src="pim1_sat/seq0_t0.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>

# %% [markdown]
# Describe the output...

# %%
IFrame('pim1_sat/seq0_t1.pdf', width=1200, height=400)
# Out:
#         <iframe
#             width="1200"
#             height="400"
#             src="pim1_sat/seq0_t1.pdf"
#             frameborder="0"
#             allowfullscreen
#         ></iframe>
